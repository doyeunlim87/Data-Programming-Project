# %%
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py
import plotly.tools as tls
import matplotlib.pyplot as plt
import io

# %%
# Out:
# 347867

# %%
# note to Bo & David:  I created another column in the Excel document titled 
# Month.  This column was created using the following function in Excel: 
# =MONTH(excel_cell_with_date)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
workbook = "C:/Users/CharlesChip/Documents/Python files/ATL Crimes YTD2017.csv"
atl_crimes = pd.read_csv(workbook)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
atl_crimes.groupby('Month')['offense_id'].count().plot(marker='o')
plt.xticks(np.arange(12), months)
plt.title("Number of Crimes by Month")
plt.ylabel('Number of Crimes')
plt.show()

# %%
# note to Bo & David:  I created another column in the Excel document titled 
# HourOfDay.  This column was created using the following function in Excel: 
# =HOUR(excel_cell_with_time)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
workbook = "C:/Users/CharlesChip/Documents/Python files/ATL Crimes YTD2017.csv"
atl_crimes = pd.read_csv(workbook)
atl_crimes.groupby('HourOfDay')['offense_id'].count().plot(marker='o', label='Crimes')
plt.ylabel('Number of Crimes')
plt.title('Daily Trend')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
workbook = "C:/Users/CharlesChip/Documents/Python files/ATL Crimes YTD2017.csv"
atl_crimes = pd.read_csv(workbook)
df = pd.read_csv(workbook2)
dfnparray = pd.DataFrame(df)
dfnparray.dropna()

def yearSum(array, year):
    yearSum = 0
    for i in range(len(array.Year)):
        if array.Year[i] == year:
            yearSum += 1
    return yearSum

def monthSum(array, month):
    monthSum = 0
    total = 0
    for i in range(len(array.Month)):
        if array.Month[i] == month:
            monthSum += 1
    for i in range(len(array.offense_id)):
        total += 1
    return monthSum/total

print("January: ", format(monthSum(dfnparray, 1), "0.3%"))
print("February: ", format(monthSum(dfnparray, 2), "0.3%"))
print("March: ", format(monthSum(dfnparray, 3), "0.3%"))
print("April: ", format(monthSum(dfnparray, 4), "0.3%"))
print("May: ", format(monthSum(dfnparray, 5), "0.3%"))
print("June: ", format(monthSum(dfnparray, 6), "0.3%"))
print("July: ", format(monthSum(dfnparray, 7), "0.3%"))
print("August: ", format(monthSum(dfnparray, 8), "0.3%"))
print("September: ", format(monthSum(dfnparray, 9), "0.3%"))
print("October: ", format(monthSum(dfnparray, 10), "0.3%"))
print("November: ", format(monthSum(dfnparray, 11), "0.3%"))
print("December: ", format(monthSum(dfnparray, 12), "0.3%"))
# Out:
# January:  8.117%
# February:  6.674%
# March:  6.405%
# April:  7.754%
# May:  8.476%
# June:  8.382%
# July:  9.160%
# August:  8.565%
# September:  9.130%
# October:  9.410%
# November:  9.040%
# December:  8.887%
